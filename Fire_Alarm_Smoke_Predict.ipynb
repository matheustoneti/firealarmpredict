# %% [markdown]
# <a href="https://colab.research.google.com/github/matheustoneti/firealarmpredict/blob/main/Fire_Alarm_Smoke_Predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier

# %%
dados = pd.read_csv('smoke_detection_iot.csv')

# %%
dados.head(10)
# Out:
#    Unnamed: 0         UTC  Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]  \
# 0           0  1654733331          20.000        57.36          0        400
# 1           1  1654733332          20.015        56.67          0        400
# 2           2  1654733333          20.029        55.96          0        400
# 3           3  1654733334          20.044        55.28          0        400
# 4           4  1654733335          20.059        54.69          0        400
# 5           5  1654733336          20.073        54.12          0        400
# 6           6  1654733337          20.088        53.61          0        400
# 7           7  1654733338          20.103        53.20          0        400
# 8           8  1654733339          20.117        52.81          0        400
# 9           9  1654733340          20.132        52.46          0        400
#
#    Raw H2  Raw Ethanol  Pressure[hPa]  PM1.0  PM2.5  NC0.5  NC1.0  NC2.5  CNT  \
# ...

# %%
dados.dropna(inplace=True)

# %%
y = dados['Fire Alarm']
x = dados.drop(['Fire Alarm'], axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = (0.3))

# %%
modelo = GradientBoostingClassifier()

# %%
modelo = modelo.fit(x_train, y_train)

# %%
score = modelo.score(x_test, y_test)

# %%
print(score)
# Out:
# 1.0
